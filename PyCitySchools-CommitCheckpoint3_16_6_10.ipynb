# %% [markdown]
# # School Data Analysis Project

# %% [markdown]
# Deliverables:
# - Table Snap Shot of key metrics for the district
# - Table of each schools key metrics
# - Table for the following:
#     - Top 5 & Bottom 5 performing schools
#     - Students Average math score per grade & school
#     - Students Average reading score per grade & school
# - Table of School Performance based on the following:
#     - Budget per student
#     - School size
#     - Type of school

# %%
import pandas as pd 
import os

# %%
#files to load 
schools_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# %%
# Read the School_data_load file by first creating a variable  to store the DataFrame. 
# End the variable with df to make it easier to refer back to it 
#Reference the Panda moduel with pd and use the read_csv() function to read the 
# the .head(fuction loads the first 5 rows of the dataFrame starting at zero)
school_data_df = pd.read_csv(schools_data_to_load)
school_data_df.head()
# Out:
#    School ID            school_name      type  size   budget
# 0          0      Huang High School  District  2917  1910635
# 1          1   Figueroa High School  District  2949  1884411
# 2          2    Shelton High School   Charter  1761  1056600
# 3          3  Hernandez High School  District  4635  3022020
# 4          4    Griffin High School   Charter  1468   917500

# %%
# the .head(fuction loads the first 5 rows of the dataFrame starting at zero)
school_data_df.tail()
# Out:
#     School ID            school_name      type  size   budget
# 10         10     Wright High School   Charter  1800  1049400
# 11         11  Rodriguez High School  District  3999  2547363
# 12         12    Johnson High School  District  4761  3094650
# 13         13       Ford High School  District  2739  1763916
# 14         14     Thomas High School   Charter  1635  1043130

# %%
#Get Indices of the DataFrame
school_data_df.index
# Out:
# RangeIndex(start=0, stop=15, step=1)

# %%
#Get column of the DataFrame
school_data_df.columns
# Out:
# Index(['School ID', 'school_name', 'type', 'size', 'budget'], dtype='object')

# %%
#Get values of the DataFrame
school_data_df.values
# Out:
# array([[0, 'Huang High School', 'District', 2917, 1910635],
#        [1, 'Figueroa High School', 'District', 2949, 1884411],
#        [2, 'Shelton High School', 'Charter', 1761, 1056600],
#        [3, 'Hernandez High School', 'District', 4635, 3022020],
#        [4, 'Griffin High School', 'Charter', 1468, 917500],
#        [5, 'Wilson High School', 'Charter', 2283, 1319574],
#        [6, 'Cabrera High School', 'Charter', 1858, 1081356],
#        [7, 'Bailey High School', 'District', 4976, 3124928],
#        [8, 'Holden High School', 'Charter', 427, 248087],
#        [9, 'Pena High School', 'Charter', 962, 585858],
#        [10, 'Wright High School', 'Charter', 1800, 1049400],
#        [11, 'Rodriguez High School', 'District', 3999, 2547363],
#        [12, 'Johnson High School', 'District', 4761, 3094650],
#        [13, 'Ford High School', 'District', 2739, 1763916],
#        [14, 'Thomas High School', 'Charter', 1635, 1043130]], dtype=object)

# %%
# Determine if there are any missing values in the school data.
#Output are the name of the column and the row that are not null
school_data_df.count()
# Out:
# School ID      15
# school_name    15
# type           15
# size           15
# budget         15
# dtype: int64

# %%
# Read the School_data_load file by first creating a variable  to store the DataFrame. 
# End the variable with df to make it easier to refer back to it 
#Reference the Panda moduel with pd and use the read_csv() function to read the 
# the .head(fuction loads the first 5 rows of the dataFrame starting at zero)
student_data_df = pd.read_csv(student_data_to_load)
student_data_df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-96-a92cd59eeee0> in <module>
#       3 #Reference the Panda moduel with pd and use the read_csv() function to read the
#       4 # the .head(fuction loads the first 5 rows of the dataFrame starting at zero)
# ----> 5 student_data_df = pd.read_csv(student_data_to_load)
#       6 student_data_df.head()
#
# ...

# %%
student_data_df.tail()
# Out:
#        Unnamed: 0  Student ID     student_name gender grade  \
# 39165       39165       39165     Donna Howard      F  12th
# 39166       39166       39166        Dawn Bell      F  10th
# 39167       39167       39167   Rebecca Tanner      F   9th
# 39168       39168       39168     Desiree Kidd      F  10th
# 39169       39169       39169  Carolyn Jackson      F  11th
#
#               school_name  reading_score  math_score
# 39165  Thomas High School             99          90
# 39166  Thomas High School             95          70
# 39167  Thomas High School             73          84
# 39168  Thomas High School             99          90
# 39169  Thomas High School             95          75

# %%
student_data_df.count()
# Out:
# Unnamed: 0       39170
# Student ID       39170
# student_name     39170
# gender           39170
# grade            39170
# school_name      39170
# reading_score    39170
# math_score       39170
# dtype: int64

# %%
# Determine if there are any missing values in the school data.
school_data_df.isnull()
# Out:
#     School ID  school_name   type   size  budget
# 0       False        False  False  False   False
# 1       False        False  False  False   False
# 2       False        False  False  False   False
# 3       False        False  False  False   False
# 4       False        False  False  False   False
# 5       False        False  False  False   False
# 6       False        False  False  False   False
# 7       False        False  False  False   False
# 8       False        False  False  False   False
# 9       False        False  False  False   False
# 10      False        False  False  False   False
# 11      False        False  False  False   False
# 12      False        False  False  False   False
# 13      False        False  False  False   False
# 14      False        False  False  False   False

# %%
# Determine if there are any missing values in the student data.
student_data_df.isnull()
# Out:
#        Unnamed: 0  Student ID  student_name  gender  grade  school_name  \
# 0           False       False         False   False  False        False
# 1           False       False         False   False  False        False
# 2           False       False         False   False  False        False
# 3           False       False         False   False  False        False
# 4           False       False         False   False  False        False
# ...           ...         ...           ...     ...    ...          ...
# 39165       False       False         False   False  False        False
# 39166       False       False         False   False  False        False
# 39167       False       False         False   False  False        False
# 39168       False       False         False   False  False        False
# 39169       False       False         False   False  False        False
#
#        reading_score  math_score
# 0              False       False
# 1              False       False
# ...

# %%
# Determine if there are any missing values in the student data.
student_data_df.isnull().sum()
# Out:
# Unnamed: 0       0
# Student ID       0
# student_name     0
# gender           0
# grade            0
# school_name      0
# reading_score    0
# math_score       0
# dtype: int64

# %%
school_data_df.notnull()
# Out:
#     School ID  school_name  type  size  budget
# 0        True         True  True  True    True
# 1        True         True  True  True    True
# 2        True         True  True  True    True
# 3        True         True  True  True    True
# 4        True         True  True  True    True
# 5        True         True  True  True    True
# 6        True         True  True  True    True
# 7        True         True  True  True    True
# 8        True         True  True  True    True
# 9        True         True  True  True    True
# 10       True         True  True  True    True
# 11       True         True  True  True    True
# 12       True         True  True  True    True
# 13       True         True  True  True    True
# 14       True         True  True  True    True

# %%
student_data_df.notnull()
# Out:
#        Unnamed: 0  Student ID  student_name  gender  grade  school_name  \
# 0            True        True          True    True   True         True
# 1            True        True          True    True   True         True
# 2            True        True          True    True   True         True
# 3            True        True          True    True   True         True
# 4            True        True          True    True   True         True
# ...           ...         ...           ...     ...    ...          ...
# 39165        True        True          True    True   True         True
# 39166        True        True          True    True   True         True
# 39167        True        True          True    True   True         True
# 39168        True        True          True    True   True         True
# 39169        True        True          True    True   True         True
#
#        reading_score  math_score
# 0               True        True
# 1               True        True
# ...

# %%
#Get the number of rows that are not null
student_data_df.notnull().sum()
# Out:
# Unnamed: 0       39170
# Student ID       39170
# student_name     39170
# gender           39170
# grade            39170
# school_name      39170
# reading_score    39170
# math_score       39170
# dtype: int64

# %%
# Determine data types for the school DataFrame.
school_data_df.dtypes
# Out:
# School ID       int64
# school_name    object
# type           object
# size            int64
# budget          int64
# dtype: object

# %%
# Determine data types for the student DataFrame.
student_data_df.dtypes
# Out:
# Unnamed: 0        int64
# Student ID        int64
# student_name     object
# gender           object
# grade            object
# school_name      object
# reading_score     int64
# math_score        int64
# dtype: object

# %%
#Merge Data Frame
#Combine the data into a single dataset 
    #Create a new Dataframe for the merge file called school_data_complete_ddf
    #The new DataFrame will result in merging DataFrame# school_data_df "located to the right"
    #Merge into student_data_df located to the "left"
    #Ue parameter"on" equal to the name of the column that appears in both DataFram "School_name"
school_data_complete_df = pd.merge(student_data_df, school_data_df, on=["school_name", "school_name"])
school_data_complete_df.head(10)
# Out:
#    Unnamed: 0  Student ID     student_name gender grade        school_name  \
# 0           0           0     Paul Bradley      M   9th  Huang High School
# 1           1           1     Victor Smith      M  12th  Huang High School
# 2           2           2  Kevin Rodriguez      M  12th  Huang High School
# 3           3           3    Richard Scott      M  12th  Huang High School
# 4           4           4       Bonnie Ray      F   9th  Huang High School
# 5           5           5    Bryan Miranda      M   9th  Huang High School
# 6           6           6    Sheena Carter      F  11th  Huang High School
# 7           7           7     Nicole Baker      F  12th  Huang High School
# 8           8           8     Michael Roth      M  10th  Huang High School
# 9           9           9   Matthew Greene      M  10th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# ...

# %%
#Get the total number of STUDENT
#declafre a new variable 
#Use the count() attribute on Student_data_complet_df file 
#Print 
student_count = school_data_complete_df.count()
student_count
# Out:
# Unnamed: 0       39170
# Student ID       39170
# student_name     39170
# gender           39170
# grade            39170
# school_name      39170
# reading_score    39170
# math_score       39170
# School ID        39170
# type             39170
# size             39170
# budget           39170
# dtype: int64

# %%
#GET TOTAL NUMMBER OF STUDENTS 
#Slect a column to the student school
school_data_complete_df["Student ID"].count()
# Out:
# 39170

# %%
#GET TOTALNUMBER OF SCHOOLS 
#Get the total number of SCHOOLS 
#declafre a new variable 
#Use the count() attribute on Student_data_complet_df file 
#Print 
school_count = school_data_df["school_name"].count()
school_count
# Out:
# 15

# %%
#GET TOTAL BUDGET 
#Calculate the totalbudget
total_budget = school_data_df["budget"].sum()
total_budget
# Out:
# 24649428

# %%
#GET THE SCORE AVERAGE: READING 
average_reading_score = school_data_complete_df["reading_score"].mean()
average_reading
# Out:
# 81.87784018381414

# %%
#GET THE SCORE AVERAGE :MATH 
average_math_score = school_data_complete_df["math_score"].mean()
average_math
# Out:
# 78.98537145774827

# %%
#DETERMINE PASSING GRADE FOR MATH ------Boolean True/False
#Result in Boolean. True student grade are <= to 70
#False student grade are not <=70

passing_math= school_data_complete_df["math_score"] <= 70
passing_math.head()
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4    False
# Name: math_score, dtype: bool

# %%
#DETERMINE PASSING GRADE FOR MATH ------Boolean True/False
#Get the Number of Students Who Passed Math and Reading
#Filter School 
#Create a new variable 
#Refrence the entire School_data_complte_df followed by 
#the specific column you want to calculate and set it equal to >=70 passing_reading = school_data_complete_df[school_data_complete_df["reading_score"] >= 70]
passing_reading = school_data_complete_df["reading_score"] <=70
passing_reading.head()
# Out:
# 0     True
# 1    False
# 2    False
# 3     True
# 4    False
# Name: reading_score, dtype: bool

# %%
#PGET THE # OF STUDENT WHO PASS MATH ASS 
#Get the Number of Students Who Passed Math and Reading
#Filter School 
#Create a new variable 
#Refrence the entire School_data_complte_df followed by 
#the specific column you want to calculate and set it equal to >=70 
passing_math = school_data_complete_df[school_data_complete_df["math_score"] >= 70]
passing_math.head()
# Out:
#    Unnamed: 0  Student ID   student_name gender grade        school_name  \
# 0           0           0   Paul Bradley      M   9th  Huang High School
# 4           4           4     Bonnie Ray      F   9th  Huang High School
# 5           5           5  Bryan Miranda      M   9th  Huang High School
# 6           6           6  Sheena Carter      F  11th  Huang High School
# 8           8           8   Michael Roth      M  10th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635
# 5             94          94          0  District  2917  1910635
# 6             82          80          0  District  2917  1910635
# 8             95          87          0  District  2917  1910635

# %%
#PASS MATH READING 
#Get the Number of Students Who Passed Math and Reading
#Filter School 
#Create a new variable 
#Refrence the entire School_data_complte_df followed by 
#the specific column you want to calculate and set it equal to >=70 
passing_reading = school_data_complete_df[school_data_complete_df["reading_score"] >= 70]
passing_reading.head()
# Out:
#    Unnamed: 0  Student ID     student_name gender grade        school_name  \
# 1           1           1     Victor Smith      M  12th  Huang High School
# 2           2           2  Kevin Rodriguez      M  12th  Huang High School
# 4           4           4       Bonnie Ray      F   9th  Huang High School
# 5           5           5    Bryan Miranda      M   9th  Huang High School
# 6           6           6    Sheena Carter      F  11th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635
# 5             94          94          0  District  2917  1910635
# 6             82          80          0  District  2917  1910635

# %%
#PASSING MATH 
# Calculate the number of students passing math.
passing_math_count = passing_math["student_name"].count()
passing_math_count
# Out:
# 29370

# %%
#PASSING REAADING
# Calculate the number of students passing reading
passing_reading_count = passing_reading["student_name"].count()
passing_reading_count
# Out:
# 33610

# %% [markdown]
# # REVIEW   4.7.6 Get the Passing Percentages
#
# # 4.7.7 Create a District Summary DataFrame

# %%
# Calculate the percent that passed math.
# Calculate the percent that passed math.
passing_math_percentage = passing_math_count / student_count *100
passing_math_percentage
# Out:
# Unnamed: 0       74.980853
# Student ID       74.980853
# student_name     74.980853
# gender           74.980853
# grade            74.980853
# school_name      74.980853
# reading_score    74.980853
# math_score       74.980853
# School ID        74.980853
# type             74.980853
# size             74.980853
# budget           74.980853
# dtype: float64

# %%
# Calculate the percent that passed reading.
passing_reading_percentage = passing_reading_count / (student_count) * 100
passing_reading_percentage
# Out:
# Unnamed: 0       85.805463
# Student ID       85.805463
# student_name     85.805463
# gender           85.805463
# grade            85.805463
# school_name      85.805463
# reading_score    85.805463
# math_score       85.805463
# School ID        85.805463
# type             85.805463
# size             85.805463
# budget           85.805463
# dtype: float64

# %%
# Calculate the students who passed both math and reading.
passing_math_reading = school_data_complete_df[(school_data_complete_df["math_score"] >= 70) & (school_data_complete_df["reading_score"] >= 70)]
passing_math_reading.head()
# Out:
#    Unnamed: 0  Student ID    student_name gender grade        school_name  \
# 4           4           4      Bonnie Ray      F   9th  Huang High School
# 5           5           5   Bryan Miranda      M   9th  Huang High School
# 6           6           6   Sheena Carter      F  11th  Huang High School
# 8           8           8    Michael Roth      M  10th  Huang High School
# 9           9           9  Matthew Greene      M  10th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 4             97          84          0  District  2917  1910635
# 5             94          94          0  District  2917  1910635
# 6             82          80          0  District  2917  1910635
# 8             95          87          0  District  2917  1910635
# 9             96          84          0  District  2917  1910635

# %%
# Calculate the number of students who passed both math and reading.
overall_passing_math_reading =passing_math_reading.student_name.count()
overall_passing_math_reading
# Out:
# 25528

# %%
# Calculate the number of students who passed both math and reading.
overall_passing_math_reading_count = passing_math_reading["student_name"].count()
overall_passing_math_reading_count
# Out:
# 25528

# %%
# Calculate the overall passing percentage.
overall_passing_percentage = overall_passing_math_reading_count / student_count * 100
overall_passing_percentage
# Out:
# Unnamed: 0       65.172326
# Student ID       65.172326
# student_name     65.172326
# gender           65.172326
# grade            65.172326
# school_name      65.172326
# reading_score    65.172326
# math_score       65.172326
# School ID        65.172326
# type             65.172326
# size             65.172326
# budget           65.172326
# dtype: float64

# %%
# Adding a list of values with keys to create a new DataFrame.
district_summary_df = pd.DataFrame(
          [{"Total Schools": school_count,
          "Total Students": student_count,
          "Total Budget": total_budget,
          "Average Math Score": average_math_score,
          "Average Reading Score": average_reading_score,
          "% Passing Math": passing_math_percentage,
         "% Passing Reading": passing_reading_percentage,
        "% Overall Passing": overall_passing_percentage}])
district_summary_df
# Out:
#    Total Schools                                     Total Students  \
# 0             15  Unnamed: 0       39170
# Student ID       39170
# ...
#
#    Total Budget  Average Math Score  Average Reading Score  \
# 0      24649428           78.985371               81.87784
#
#                                       % Passing Math  \
# 0  Unnamed: 0       74.980853
# Student ID       74...
#
#                                    % Passing Reading  \
# 0  Unnamed: 0       85.805463
# Student ID       85...
#
#                                    % Overall Passing
# 0  Unnamed: 0       65.172326
# Student ID       65...
